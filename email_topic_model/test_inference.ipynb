# %% [markdown]
# ## **Name: Test Inference **
#
# **Overview:** Performing inference on the test dataset and exploring the results
#
# **Data Scientist:** Aaron Medina
#
# **GitHub:**
#
# **Creation Date:** 10/27/2022
#
# **Instance:** Local
#
# **References:**
#
# **Script Change Notes:**
#
# x/x/xxxx: Aaron - Note

# %%
# Import required packages
import pickle
import numpy as np
import pandas as pd

# %%
# Initialize parameters
test_corpus_path = 'data/test_corpus.pkl'
test_pdf_path = 'data/test_pdf.pkl'
tf_vectorizer_model_path = 'models/tf_vectorizer_model.pkl'
tfidf_vectorizer_model_path = 'models/tfidf_vectorizer_model.pkl'
topic_dict_path = 'data/topic_dict.pkl'
lda_model_path = 'models/lda_model.pkl'

# %%
# Load data and NLP models
test_corpus = pickle.load(open(test_corpus_path, "rb"))
test_pdf = pickle.load(open(test_pdf_path, "rb"))
tf_vectorizer_model = pickle.load(open(tf_vectorizer_model_path, "rb"))
tfidf_vectorizer_model = pickle.load(open(tfidf_vectorizer_model_path, "rb"))
topic_dict = pickle.load(open(topic_dict_path, "rb"))
lda_model = pickle.load(open(lda_model_path, "rb"))

# %%
# Transform and predict on test corpus
test_matrix = tf_vectorizer_model.transform(test_corpus)
test_matrix = tfidf_vectorizer_model.transform(test_corpus)

predictions = lda_model.transform(test_matrix)
print("Number of test samples:", len(predictions))
# Out:
# Number of test samples: 540

# %%
# Declare the assignments of topics based on review, save dictionary for inference mapping
test_pdf['prediction'] = np.argmax(predictions, axis = 1)
test_pdf = test_pdf.replace({'prediction': topic_dict})
test_pdf[['sender', 'final_body', 'prediction']].head(50)
# Out:
#                                                  sender  \
# 179              "Amazon.com" <auto-confirm@amazon.com>
# 2158  "E*TRADE Securities" <ETRADE@e.etradefinancial...
# 2475         The New York Times <nytdirect@nytimes.com>
# 2115             Peacock <no-reply@email.peacocktv.com>
# 2509         The New York Times <nytdirect@nytimes.com>
# 1096       MyFitnessPal <hello@e.blog.myfitnesspal.com>
# 1383                          Petco <Petco@e.petco.com>
# 2489         The New York Times <nytdirect@nytimes.com>
# 1628                Adobe Acrobat <mail@mail.adobe.com>
# 1408            Chick-fil-A <one@email.chick-fil-a.com>
# 406                           Petco <Petco@e.petco.com>
# 94    Animal Care Center Of Aurora <info@mail.vetsou...
# 1045       MyFitnessPal <hello@e.blog.myfitnesspal.com>
# 2611              Google <no-reply@accounts.google.com>
# 1192     Zoom Video Communications <webinars@e.zoom.us>
# 383       FirstLight FCU  <marketing@firstlightfcu.org>
# 1538                           Get2it <info@get2it.com>
# 1848                        Toyota <email@e.toyota.com>
# 1320                              newaccount@bellco.org
# 2095             Peacock <no-reply@email.peacocktv.com>
# 1801  Jacqueline Kennedy <jacqueline@jacqueline-kenn...
# 267      Zoom Video Communications <teamzoom@e.zoom.us>
# 1196        MyFitnessPal <hello@email.myfitnesspal.com>
# 2316           Medium Daily Digest <noreply@medium.com>
# 1524  Jacqueline Kennedy <jacqueline@jacqueline-kenn...
# 84            The Exchange <email@e.shopmyexchange.com>
# 1948          State Farm <statefarm@mail.statefarm.com>
# 1354                    MOD Pizza <offers@modpizza.com>
# 2607            Chick-fil-A <one@email.chick-fil-a.com>
# 216                          no_reply@conservetrack.com
# 1093  PENNYMAC <cust-homeloansolutions@em.pennymac.com>
# 2608  Pinterest <pinterest-recommendations@ideas.pin...
# 1444            Chick-fil-A <one@email.chick-fil-a.com>
# 1243               Old Navy <oldnavy@email.oldnavy.com>
# 1578          The Exchange <email@e.shopmyexchange.com>
# 1415            Trent Peaker <tp@megastarfinancial.com>
# 856        MyFitnessPal <hello@e.blog.myfitnesspal.com>
# 2631            Chick-fil-A <one@email.chick-fil-a.com>
# 180           Chris Maers <chris.maers@mail.fetcher.ai>
# 121           Chris Maers <chris.maers@mail.fetcher.ai>
# 2524           Medium Daily Digest <noreply@medium.com>
# 2412         The New York Times <nytdirect@nytimes.com>
# 2644            Chick-fil-A <one@email.chick-fil-a.com>
# 258                           Petco <Petco@e.petco.com>
# 185                       Amica Life <Survey@amica.com>
# 899           The Exchange <email@e.shopmyexchange.com>
# 515   Nextdoor Southshore <reply@rs.email.nextdoor.com>
# 447        MyFitnessPal <hello@e.blog.myfitnesspal.com>
# 1567  Valley Modern Dentists <ValleyModernDentists@m...
# 2613            Adriana Medina <almedina@aurorak12.org>
#
#                                              final_body  \
# 179                              amazon com order unnam
# 2158  aaron go paperless world good   browser log he...
# 2475  wednesday morn riot polit   browser nytim com ...
# 2115  new movi show plu check alway channel peacock ...
# 2509  thursday morn europ big problem   browser nyti...
# 1096  easiest sheet pan shrimp  ri rice plu spring  ...
# 1383  order way order deliveri hi aaron thank shop p...
# 2489  weekend brie    browser nytim comaugust remi t...
# 1628  sleigh way holiday glori   web version un ortu...
# 1408                                       deliveri  ee
# 406   miss labor day sale almost labor day sale almo...
# 94    coupon wait aaron vetsourc visit onlin store s...
# 1045  hot weather weight loss hack summer plu sneaki...
# 2611  secur alert   googl new devic sign aaronjmedin...
# 1192  miss new zoom titl sign rsquo new zoom thursda...
# 383   re d member bene it activ two cash bene it hel...
# 1538  val in day  ip swoon     web page go  ollow ad...
# 1848  aaron new tundra reveal toyotawherev head read...
# 1320  bellco credit union applic approv doctyp html ...
# 2095  set pro il everyon  lock custom   experi peaco...
# 1801                             halloween denver unnam
# 267   zoom alon invit  riend earn reward love zoom s...
# 1196  take he back premium join nearli user achiev h...
# 2316  python skill teach bootcamp nicol janeway bill...
# 1524                                     ice  est unnam
# 84    new season new nba gear exchang tax    shop   ...
# 1948  new way live g ner plu  it everi sur ac car so...
# 1354  make meal earn bonu point order today get rewa...
# 2607                  earn bonu point april mobil order
# 216                                                 nan
# 1093                        may elig get cash get start
# 2608  diy rais garden starwar board like      open  ...
# 1444                                 eel like chick  il
# 1243  deserv jean ye deal deserv jean ye deal plu na...
# 1578  take bite appl exchang tax    shop     onlin l...
# 1415  happi presid day happi presid day aaron celebr...
# 856   stand desk help burn calori plu guid start car...
# 2631                      action take around coronaviru
# 180   data engin opportun  ulli remot air low snow l...
# 121   data engin opportun  ulli remot air low snow l...
# 2524  joe biden victori could chang coun i  orev eri...
# 2412  wednesday morn  ump win   browser nytim comse ...
# 2644                        aaron easier order tap away
# 258   new  all   nikita love product price     may m...
# 185   re d amica li need input listen voic count dea...
# 899   dad go love exchang tax    shop     onlin  ind...
# 515   anyon interest weed nex oor nex oor southshor ...
# 447   power walk program build  it plu learn per ect...
# 1567  he hier happier holiday hour say hello meet ty...
# 2613                                 morn work s  iphon
#
#                         prediction
# 179   social media / subscriptions
# 2158  social media / subscriptions
# 2475  social media / subscriptions
# 2115  social media / subscriptions
# 2509  social media / subscriptions
# 1096        articles / connections
# 1383        articles / connections
# 2489  social media / subscriptions
# 1628  social media / subscriptions
# 1408  social media / subscriptions
# 406         articles / connections
# 94          articles / connections
# 1045        articles / connections
# 2611  social media / subscriptions
# 1192  social media / subscriptions
# 383         articles / connections
# 1538  social media / subscriptions
# 1848  social media / subscriptions
# 1320        articles / connections
# 2095  social media / subscriptions
# 1801  social media / subscriptions
# 267   social media / subscriptions
# 1196        articles / connections
# 2316  social media / subscriptions
# 1524  social media / subscriptions
# 84             offers / promotions
# 1948  social media / subscriptions
# 1354  social media / subscriptions
# 2607  social media / subscriptions
# 216            offers / promotions
# 1093           offers / promotions
# 2608  social media / subscriptions
# 1444  social media / subscriptions
# 1243  social media / subscriptions
# 1578           offers / promotions
# 1415  social media / subscriptions
# 856         articles / connections
# 2631  social media / subscriptions
# 180   social media / subscriptions
# 121   social media / subscriptions
# 2524  social media / subscriptions
# 2412  social media / subscriptions
# 2644        articles / connections
# 258         articles / connections
# 185   social media / subscriptions
# 899            offers / promotions
# 515   social media / subscriptions
# 447         articles / connections
# 1567  social media / subscriptions
# 2613  social media / subscriptions
